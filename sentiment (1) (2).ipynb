# %%
! pip install pandas
! pip install scikit-learn
! pip install xgboost
! pip install mwclient
! pip install yfinance
! pip install matplotlib
! pip install transformers
# Out:
# Requirement already satisfied: pandas in c:\users\peggy\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\peggy\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\peggy\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\peggy\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in c:\users\peggy\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\peggy\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\peggy\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\peggy\anaconda3\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\peggy\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\peggy\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: xgboost in c:\users\peggy\anaconda3\lib\site-packages (1.7.6)
# Requirement already satisfied: scipy in c:\users\peggy\anaconda3\lib\site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: numpy in c:\users\peggy\anaconda3\lib\site-packages (from xgboost) (1.23.5)
# Requirement already satisfied: mwclient in c:\users\peggy\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: requests-oauthlib in c:\users\peggy\anaconda3\lib\site-packages (from mwclient) (1.3.1)
# Requirement already satisfied: six in c:\users\peggy\anaconda3\lib\site-packages (from mwclient) (1.16.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\peggy\anaconda3\lib\site-packages (from requests-oauthlib->mwclient) (2.28.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\peggy\anaconda3\lib\site-packages (from requests-oauthlib->mwclient) (3.2.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\peggy\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\peggy\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\peggy\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\peggy\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib->mwclient) (2022.12.7)
# Requirement already satisfied: yfinance in c:\users\peggy\anaconda3\lib\site-packages (0.2.24)
# Requirement already satisfied: requests>=2.26 in c:\users\peggy\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: pytz>=2022.5 in c:\users\peggy\anaconda3\lib\site-packages (from yfinance) (2022.7)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\peggy\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\peggy\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\peggy\anaconda3\lib\site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\peggy\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\peggy\anaconda3\lib\site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\peggy\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\peggy\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\peggy\anaconda3\lib\site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\peggy\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\peggy\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\peggy\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\peggy\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\peggy\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\peggy\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\peggy\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\peggy\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: matplotlib in c:\users\peggy\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\peggy\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\peggy\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\peggy\anaconda3\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\peggy\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\peggy\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\peggy\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\peggy\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\peggy\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\peggy\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\peggy\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: transformers in c:\users\peggy\anaconda3\lib\site-packages (4.24.0)
# Requirement already satisfied: filelock in c:\users\peggy\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\peggy\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\peggy\anaconda3\lib\site-packages (from transformers) (0.11.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\peggy\anaconda3\lib\site-packages (from transformers) (22.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\peggy\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\peggy\anaconda3\lib\site-packages (from transformers) (0.10.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\peggy\anaconda3\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: requests in c:\users\peggy\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\peggy\anaconda3\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\peggy\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: colorama in c:\users\peggy\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\peggy\anaconda3\lib\site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\peggy\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\peggy\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\peggy\anaconda3\lib\site-packages (from requests->transformers) (2022.12.7)

# %%
import mwclient
import time

site = mwclient.Site('en.wikipedia.org')
page = site.pages['Hermès']

# %%
revs = list(page.revisions())

# %%
revs[0]
# Out:
# OrderedDict([('revid', 1159933895),
#              ('parentid', 1158710120),
#              ('user', 'Keisigei'),
#              ('timestamp',
#               time.struct_time(tm_year=2023, tm_mon=6, tm_mday=13, tm_hour=13, tm_min=4, tm_sec=57, tm_wday=1, tm_yday=164, tm_isdst=-1)),
#              ('comment', '/* Hermès Frères era */')])

# %%
revs = sorted(revs, key=lambda rev: rev["timestamp"])

# %%
revs[0]
# Out:
# OrderedDict([('revid', 14874635),
#              ('parentid', 0),
#              ('user', 'Ted Wilkes'),
#              ('timestamp',
#               time.struct_time(tm_year=2005, tm_mon=6, tm_mday=8, tm_hour=13, tm_min=16, tm_sec=17, tm_wday=2, tm_yday=159, tm_isdst=-1)),
#              ('comment', 'made new stub article')])

# %%
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis")

def find_sentiment(text):
    sent = sentiment_pipeline([text[:250]])[0]
    score = sent["score"]
    if sent["label"] == "NEGATIVE":
        score *= -1
    return score
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
edits = {}

for rev in revs:        
    date = time.strftime("%Y-%m-%d", rev["timestamp"])
    if date not in edits:
        edits[date] = dict(sentiments=list(), edit_count=0)
    
    edits[date]["edit_count"] += 1
    
    comment = rev.get("comment", "")
    edits[date]["sentiments"].append(find_sentiment(comment))

# %%
from statistics import mean
for key in edits:
    if "sentiments" in edits[key]:
        if len(edits[key]["sentiments"]) > 0:
            edits[key]["sentiment"] = mean(edits[key]["sentiments"])
            edits[key]["neg_sentiment"] = len([s for s in edits[key]["sentiments"] if s < 0]) / len(edits[key]["sentiments"])
        else:
            edits[key]["sentiment"] = 0
            edits[key]["neg_sentiment"] = 0
        del edits[key]["sentiments"]

# %%
edits
# Out:
# {'2005-06-08': {'edit_count': 3,
#   'sentiment': 0.17164989312489828,
#   'neg_sentiment': 0.3333333333333333},
#  '2005-06-19': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2005-06-24': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2005-06-25': {'edit_count': 2,
#   'sentiment': 0.8721365034580231,
#   'neg_sentiment': 0.0},
#  '2005-06-28': {'edit_count': 1,
#   'sentiment': -0.9986476302146912,
#   'neg_sentiment': 1.0},
#  '2005-06-30': {'edit_count': 1,
#   'sentiment': -0.9989820122718811,
#   'neg_sentiment': 1.0},
#  '2005-07-05': {'edit_count': 1,
#   'sentiment': 0.9987383484840393,
#   'neg_sentiment': 0.0},
#  '2005-07-19': {'edit_count': 1,
#   'sentiment': 0.9797213077545166,
#   'neg_sentiment': 0.0},
#  '2005-07-22': {'edit_count': 1,
#   'sentiment': -0.9973267316818237,
#   'neg_sentiment': 1.0},
#  '2005-07-31': {'edit_count': 1,
#   'sentiment': 0.9947939515113831,
#   'neg_sentiment': 0.0},
#  '2005-08-26': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2005-09-15': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2005-09-21': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2005-09-23': {'edit_count': 2,
#   'sentiment': 0.8647874593734741,
#   'neg_sentiment': 0.0},
#  '2005-09-24': {'edit_count': 1,
#   'sentiment': 0.9079540967941284,
#   'neg_sentiment': 0.0},
#  '2005-09-25': {'edit_count': 1,
#   'sentiment': 0.9592428207397461,
#   'neg_sentiment': 0.0},
#  '2005-10-10': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2005-10-17': {'edit_count': 1,
#   'sentiment': 0.9851985573768616,
#   'neg_sentiment': 0.0},
#  '2005-10-25': {'edit_count': 1,
#   'sentiment': -0.9959238767623901,
#   'neg_sentiment': 1.0},
#  '2005-11-04': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2005-11-09': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2005-11-10': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2005-11-12': {'edit_count': 1,
#   'sentiment': -0.9976058006286621,
#   'neg_sentiment': 1.0},
#  '2005-11-15': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2005-11-19': {'edit_count': 1,
#   'sentiment': -0.9997616410255432,
#   'neg_sentiment': 1.0},
#  '2005-11-22': {'edit_count': 1,
#   'sentiment': -0.952399492263794,
#   'neg_sentiment': 1.0},
#  '2005-12-01': {'edit_count': 1,
#   'sentiment': -0.9883070588111877,
#   'neg_sentiment': 1.0},
#  '2005-12-03': {'edit_count': 1,
#   'sentiment': -0.9991600513458252,
#   'neg_sentiment': 1.0},
#  '2005-12-18': {'edit_count': 6,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2005-12-28': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-01-02': {'edit_count': 3,
#   'sentiment': 0.17276151974995932,
#   'neg_sentiment': 0.3333333333333333},
#  '2006-01-27': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-01-29': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-01-30': {'edit_count': 2,
#   'sentiment': -0.10805559158325195,
#   'neg_sentiment': 0.5},
#  '2006-02-03': {'edit_count': 2,
#   'sentiment': -0.018690258264541626,
#   'neg_sentiment': 0.5},
#  '2006-02-08': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-02-17': {'edit_count': 1,
#   'sentiment': 0.9843908548355103,
#   'neg_sentiment': 0.0},
#  '2006-02-24': {'edit_count': 1,
#   'sentiment': -0.8967692255973816,
#   'neg_sentiment': 1.0},
#  '2006-03-07': {'edit_count': 14,
#   'sentiment': 0.8658877696309771,
#   'neg_sentiment': 0.0},
#  '2006-03-13': {'edit_count': 2,
#   'sentiment': 0.9986295700073242,
#   'neg_sentiment': 0.0},
#  '2006-03-14': {'edit_count': 1,
#   'sentiment': -0.993719220161438,
#   'neg_sentiment': 1.0},
#  '2006-03-23': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-04-02': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-04-08': {'edit_count': 1,
#   'sentiment': 0.9986295700073242,
#   'neg_sentiment': 0.0},
#  '2006-04-21': {'edit_count': 1,
#   'sentiment': 0.9479965567588806,
#   'neg_sentiment': 0.0},
#  '2006-04-29': {'edit_count': 1,
#   'sentiment': -0.9971252083778381,
#   'neg_sentiment': 1.0},
#  '2006-05-03': {'edit_count': 1,
#   'sentiment': 0.9986295700073242,
#   'neg_sentiment': 0.0},
#  '2006-05-06': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-05-19': {'edit_count': 2,
#   'sentiment': 0.9986295700073242,
#   'neg_sentiment': 0.0},
#  '2006-06-01': {'edit_count': 3,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-07-05': {'edit_count': 8,
#   'sentiment': 0.8359656631946564,
#   'neg_sentiment': 0.0},
#  '2006-07-06': {'edit_count': 3,
#   'sentiment': 0.311190664768219,
#   'neg_sentiment': 0.3333333333333333},
#  '2006-07-16': {'edit_count': 1,
#   'sentiment': -0.9994586110115051,
#   'neg_sentiment': 1.0},
#  '2006-07-26': {'edit_count': 1,
#   'sentiment': 0.9986295700073242,
#   'neg_sentiment': 0.0},
#  '2006-07-31': {'edit_count': 1,
#   'sentiment': 0.9300209879875183,
#   'neg_sentiment': 0.0},
#  '2006-08-03': {'edit_count': 2,
#   'sentiment': -0.00638166069984436,
#   'neg_sentiment': 0.5},
#  '2006-08-04': {'edit_count': 4,
#   'sentiment': 0.7499859929084778,
#   'neg_sentiment': 0.0},
#  '2006-08-06': {'edit_count': 3,
#   'sentiment': 0.9047822952270508,
#   'neg_sentiment': 0.0},
#  '2006-08-18': {'edit_count': 1,
#   'sentiment': 0.9986295700073242,
#   'neg_sentiment': 0.0},
#  '2006-08-19': {'edit_count': 1,
#   'sentiment': 0.9986295700073242,
#   'neg_sentiment': 0.0},
#  '2006-08-21': {'edit_count': 1,
#   'sentiment': -0.8142879009246826,
#   'neg_sentiment': 1.0},
#  '2006-08-27': {'edit_count': 2,
#   'sentiment': -0.10805907845497131,
#   'neg_sentiment': 0.5},
#  '2006-09-07': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-09-09': {'edit_count': 1,
#   'sentiment': 0.9300209879875183,
#   'neg_sentiment': 0.0},
#  '2006-09-14': {'edit_count': 3,
#   'sentiment': 0.29420894384384155,
#   'neg_sentiment': 0.3333333333333333},
#  '2006-09-17': {'edit_count': 1,
#   'sentiment': 0.9986295700073242,
#   'neg_sentiment': 0.0},
#  '2006-09-19': {'edit_count': 2,
#   'sentiment': -0.0002707839012145996,
#   'neg_sentiment': 0.5},
#  '2006-09-22': {'edit_count': 1,
#   'sentiment': 0.9104663133621216,
#   'neg_sentiment': 0.0},
#  '2006-09-27': {'edit_count': 4,
#   'sentiment': 0.923344150185585,
#   'neg_sentiment': 0.0},
#  '2006-09-28': {'edit_count': 1,
#   'sentiment': 0.8328018188476562,
#   'neg_sentiment': 0.0},
#  '2006-10-04': {'edit_count': 3,
#   'sentiment': -0.4166895349820455,
#   'neg_sentiment': 0.6666666666666666},
#  '2006-10-18': {'edit_count': 1,
#   'sentiment': -0.9911956787109375,
#   'neg_sentiment': 1.0},
#  '2006-10-20': {'edit_count': 2,
#   'sentiment': -0.12459257245063782,
#   'neg_sentiment': 0.5},
#  '2006-11-04': {'edit_count': 2,
#   'sentiment': 0.8695808351039886,
#   'neg_sentiment': 0.0},
#  '2006-11-07': {'edit_count': 3,
#   'sentiment': 0.1744006077448527,
#   'neg_sentiment': 0.3333333333333333},
#  '2006-11-08': {'edit_count': 2,
#   'sentiment': -0.8185072541236877,
#   'neg_sentiment': 1.0},
#  '2006-11-13': {'edit_count': 3,
#   'sentiment': 0.2323154409726461,
#   'neg_sentiment': 0.3333333333333333},
#  '2006-11-17': {'edit_count': 1,
#   'sentiment': 0.9479965567588806,
#   'neg_sentiment': 0.0},
#  '2006-11-18': {'edit_count': 1,
#   'sentiment': 0.9300209879875183,
#   'neg_sentiment': 0.0},
#  '2006-11-19': {'edit_count': 1,
#   'sentiment': 0.9479965567588806,
#   'neg_sentiment': 0.0},
#  '2006-11-22': {'edit_count': 2,
#   'sentiment': -0.08789125084877014,
#   'neg_sentiment': 0.5},
#  '2006-11-27': {'edit_count': 1,
#   'sentiment': -0.8911853432655334,
#   'neg_sentiment': 1.0},
#  '2006-12-08': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-12-12': {'edit_count': 3,
#   'sentiment': 0.25989753007888794,
#   'neg_sentiment': 0.3333333333333333},
#  '2006-12-13': {'edit_count': 3,
#   'sentiment': -0.40062302350997925,
#   'neg_sentiment': 0.6666666666666666},
#  '2006-12-19': {'edit_count': 2,
#   'sentiment': 0.6815157234668732,
#   'neg_sentiment': 0.0},
#  '2006-12-20': {'edit_count': 3,
#   'sentiment': 0.9163324435551962,
#   'neg_sentiment': 0.0},
#  '2006-12-24': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-12-29': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2006-12-30': {'edit_count': 1,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2006-12-31': {'edit_count': 2,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2007-01-02': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-01-04': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-01-13': {'edit_count': 2,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-01-14': {'edit_count': 1,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2007-01-15': {'edit_count': 1,
#   'sentiment': -0.9699198603630066,
#   'neg_sentiment': 1.0},
#  '2007-02-01': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-02-05': {'edit_count': 2,
#   'sentiment': -0.8893657922744751,
#   'neg_sentiment': 1.0},
#  '2007-02-06': {'edit_count': 3,
#   'sentiment': 0.12437234322230022,
#   'neg_sentiment': 0.3333333333333333},
#  '2007-02-10': {'edit_count': 1,
#   'sentiment': -0.9553942680358887,
#   'neg_sentiment': 1.0},
#  '2007-02-11': {'edit_count': 2,
#   'sentiment': 0.7688337862491608,
#   'neg_sentiment': 0.0},
#  '2007-02-13': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-02-14': {'edit_count': 2,
#   'sentiment': -0.0435185432434082,
#   'neg_sentiment': 0.5},
#  '2007-02-17': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-02-18': {'edit_count': 1,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2007-02-19': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-02-23': {'edit_count': 1,
#   'sentiment': 0.9034832715988159,
#   'neg_sentiment': 0.0},
#  '2007-02-24': {'edit_count': 1,
#   'sentiment': -0.9935798645019531,
#   'neg_sentiment': 1.0},
#  '2007-02-25': {'edit_count': 3,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-02-26': {'edit_count': 5,
#   'sentiment': 0.472939133644104,
#   'neg_sentiment': 0.2},
#  '2007-02-27': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-03-01': {'edit_count': 12,
#   'sentiment': 0.8437827825546265,
#   'neg_sentiment': 0.0},
#  '2007-03-02': {'edit_count': 2,
#   'sentiment': -0.1244162917137146,
#   'neg_sentiment': 0.5},
#  '2007-03-03': {'edit_count': 1,
#   'sentiment': 0.9964852333068848,
#   'neg_sentiment': 0.0},
#  '2007-03-04': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-03-05': {'edit_count': 2,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-03-07': {'edit_count': 2,
#   'sentiment': -0.04072016477584839,
#   'neg_sentiment': 0.5},
#  '2007-03-08': {'edit_count': 1,
#   'sentiment': 0.88155597448349,
#   'neg_sentiment': 0.0},
#  '2007-03-11': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-03-14': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-03-16': {'edit_count': 5,
#   'sentiment': 0.553082001209259,
#   'neg_sentiment': 0.2},
#  '2007-03-19': {'edit_count': 1,
#   'sentiment': 0.8337069749832153,
#   'neg_sentiment': 0.0},
#  '2007-03-23': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-03-27': {'edit_count': 1,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2007-03-30': {'edit_count': 2,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2007-04-01': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-04-02': {'edit_count': 1,
#   'sentiment': 0.9522356986999512,
#   'neg_sentiment': 0.0},
#  '2007-04-07': {'edit_count': 4,
#   'sentiment': 0.9043062031269073,
#   'neg_sentiment': 0.0},
#  '2007-04-08': {'edit_count': 1,
#   'sentiment': -0.9981189370155334,
#   'neg_sentiment': 1.0},
#  '2007-04-11': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-04-14': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-04-15': {'edit_count': 3,
#   'sentiment': 0.9097226063410441,
#   'neg_sentiment': 0.0},
#  '2007-04-16': {'edit_count': 15,
#   'sentiment': 0.31612071990966795,
#   'neg_sentiment': 0.3333333333333333},
#  '2007-04-19': {'edit_count': 3,
#   'sentiment': 0.8147461215655009,
#   'neg_sentiment': 0.0},
#  '2007-04-25': {'edit_count': 1,
#   'sentiment': 0.6161511540412903,
#   'neg_sentiment': 0.0},
#  '2007-04-27': {'edit_count': 1,
#   'sentiment': -0.9952899217605591,
#   'neg_sentiment': 1.0},
#  '2007-04-29': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-05-01': {'edit_count': 4,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-05-02': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-05-07': {'edit_count': 2,
#   'sentiment': 0.10731226205825806,
#   'neg_sentiment': 0.5},
#  '2007-05-08': {'edit_count': 1,
#   'sentiment': -0.9949454665184021,
#   'neg_sentiment': 1.0},
#  '2007-05-22': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-05-24': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-05-28': {'edit_count': 1,
#   'sentiment': -0.9976049661636353,
#   'neg_sentiment': 1.0},
#  '2007-05-31': {'edit_count': 2,
#   'sentiment': -0.9559509754180908,
#   'neg_sentiment': 1.0},
#  '2007-06-01': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-06-05': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-06-06': {'edit_count': 2,
#   'sentiment': 0.0702848732471466,
#   'neg_sentiment': 0.5},
#  '2007-06-08': {'edit_count': 2,
#   'sentiment': -0.8366863131523132,
#   'neg_sentiment': 1.0},
#  '2007-06-12': {'edit_count': 4,
#   'sentiment': 0.07391685247421265,
#   'neg_sentiment': 0.5},
#  '2007-06-20': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-06-21': {'edit_count': 2,
#   'sentiment': -0.03742396831512451,
#   'neg_sentiment': 0.5},
#  '2007-06-23': {'edit_count': 2,
#   'sentiment': 0.0005952715873718262,
#   'neg_sentiment': 0.5},
#  '2007-06-27': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-07-01': {'edit_count': 2,
#   'sentiment': -0.12488877773284912,
#   'neg_sentiment': 0.5},
#  '2007-07-02': {'edit_count': 1,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2007-07-04': {'edit_count': 1,
#   'sentiment': -0.5717839598655701,
#   'neg_sentiment': 1.0},
#  '2007-07-05': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-07-14': {'edit_count': 1,
#   'sentiment': 0.9968118071556091,
#   'neg_sentiment': 0.0},
#  '2007-07-17': {'edit_count': 1,
#   'sentiment': -0.9991500377655029,
#   'neg_sentiment': 1.0},
#  '2007-07-21': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-07-23': {'edit_count': 1,
#   'sentiment': -0.9997264742851257,
#   'neg_sentiment': 1.0},
#  '2007-07-31': {'edit_count': 2,
#   'sentiment': -0.9995013177394867,
#   'neg_sentiment': 1.0},
#  '2007-08-02': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-08-03': {'edit_count': 2,
#   'sentiment': 0.9021565020084381,
#   'neg_sentiment': 0.0},
#  '2007-08-04': {'edit_count': 2,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2007-08-09': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-08-13': {'edit_count': 2,
#   'sentiment': 0.8480587303638458,
#   'neg_sentiment': 0.0},
#  '2007-08-22': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-08-23': {'edit_count': 2,
#   'sentiment': -0.01703318953514099,
#   'neg_sentiment': 0.5},
#  '2007-08-31': {'edit_count': 3,
#   'sentiment': 0.2649650772412618,
#   'neg_sentiment': 0.3333333333333333},
#  '2007-09-05': {'edit_count': 1,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2007-09-06': {'edit_count': 2,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-09-08': {'edit_count': 1,
#   'sentiment': 0.9479965567588806,
#   'neg_sentiment': 0.0},
#  '2007-09-10': {'edit_count': 5,
#   'sentiment': 0.21353980302810668,
#   'neg_sentiment': 0.4},
#  '2007-09-13': {'edit_count': 1,
#   'sentiment': 0.9479965567588806,
#   'neg_sentiment': 0.0},
#  '2007-09-18': {'edit_count': 6,
#   'sentiment': 0.6258789797623953,
#   'neg_sentiment': 0.16666666666666666},
#  '2007-09-19': {'edit_count': 3,
#   'sentiment': 0.3007635672887166,
#   'neg_sentiment': 0.3333333333333333},
#  '2007-09-24': {'edit_count': 2,
#   'sentiment': 0.9479965567588806,
#   'neg_sentiment': 0.0},
#  '2007-10-02': {'edit_count': 1,
#   'sentiment': 0.9479965567588806,
#   'neg_sentiment': 0.0},
#  '2007-10-10': {'edit_count': 2,
#   'sentiment': -0.01703318953514099,
#   'neg_sentiment': 0.5},
#  '2007-10-13': {'edit_count': 1,
#   'sentiment': 0.9995980858802795,
#   'neg_sentiment': 0.0},
#  '2007-10-16': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-10-29': {'edit_count': 1,
#   'sentiment': -0.9676868319511414,
#   'neg_sentiment': 1.0},
#  '2007-11-03': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2007-11-04': {'edit_count': 1,
#   'sentiment': -0.9980643391609192,
#   'neg_sentiment': 1.0},
#  '2007-11-10': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-11-11': {'edit_count': 1,
#   'sentiment': -0.9982004165649414,
#   'neg_sentiment': 1.0},
#  '2007-11-17': {'edit_count': 5,
#   'sentiment': 0.9185670614242554,
#   'neg_sentiment': 0.0},
#  '2007-11-19': {'edit_count': 2,
#   'sentiment': 0.001508265733718872,
#   'neg_sentiment': 0.5},
#  '2007-11-27': {'edit_count': 1,
#   'sentiment': -0.7150126695632935,
#   'neg_sentiment': 1.0},
#  '2007-11-29': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2007-12-04': {'edit_count': 2,
#   'sentiment': 0.8989408314228058,
#   'neg_sentiment': 0.0},
#  '2007-12-09': {'edit_count': 1,
#   'sentiment': 0.9479965567588806,
#   'neg_sentiment': 0.0},
#  '2007-12-14': {'edit_count': 2,
#   'sentiment': 0.9914695918560028,
#   'neg_sentiment': 0.0},
#  '2007-12-15': {'edit_count': 7,
#   'sentiment': -0.9924342461994716,
#   'neg_sentiment': 1.0},
#  '2007-12-20': {'edit_count': 2,
#   'sentiment': 0.9479965567588806,
#   'neg_sentiment': 0.0},
#  '2007-12-31': {'edit_count': 3,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2008-01-02': {'edit_count': 1,
#   'sentiment': 0.9479965567588806,
#   'neg_sentiment': 0.0},
#  '2008-01-04': {'edit_count': 1,
#   'sentiment': 0.6039772033691406,
#   'neg_sentiment': 0.0},
#  '2008-01-09': {'edit_count': 1,
#   'sentiment': -0.9067828059196472,
#   'neg_sentiment': 1.0},
#  '2008-01-22': {'edit_count': 2,
#   'sentiment': 0.0829046368598938,
#   'neg_sentiment': 0.5},
#  '2008-01-26': {'edit_count': 1,
#   'sentiment': 0.5432817339897156,
#   'neg_sentiment': 0.0},
#  '2008-01-27': {'edit_count': 9,
#   'sentiment': -0.5005310773849487,
#   'neg_sentiment': 0.7777777777777778},
#  '2008-02-02': {'edit_count': 1,
#   'sentiment': 0.5345741510391235,
#   'neg_sentiment': 0.0},
#  '2008-02-04': {'edit_count': 1,
#   'sentiment': -0.9991803765296936,
#   'neg_sentiment': 1.0},
#  '2008-02-06': {'edit_count': 1,
#   'sentiment': -0.9995256662368774,
#   'neg_sentiment': 1.0},
#  '2008-02-08': {'edit_count': 2,
#   'sentiment': -0.01703318953514099,
#   'neg_sentiment': 0.5},
#  '2008-02-10': {'edit_count': 4,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2008-02-12': {'edit_count': 1,
#   'sentiment': 0.9968118071556091,
#   'neg_sentiment': 0.0},
#  '2008-02-13': {'edit_count': 1,
#   'sentiment': 0.8836537599563599,
#   'neg_sentiment': 0.0},
#  '2008-02-15': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2008-02-18': {'edit_count': 1,
#   'sentiment': 0.7499859929084778,
#   'neg_sentiment': 0.0},
#  '2008-02-26': {'edit_count': 1,
#   'sentiment': -0.9915075302124023,
#   'neg_sentiment': 1.0},
#  '2008-02-27': {'edit_count': 2,
#   'sentiment': 0.9968118071556091,
#   'neg_sentiment': 0.0},
#  '2008-03-03': {'edit_count': 1,
#   'sentiment': 0.7499859929084778,
#   'neg_sentiment': 0.0},
#  '2008-03-07': {'edit_count': 1,
#   'sentiment': -0.9995520710945129,
#   'neg_sentiment': 1.0},
#  '2008-03-10': {'edit_count': 1,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2008-03-11': {'edit_count': 1,
#   'sentiment': 0.9243648052215576,
#   'neg_sentiment': 0.0},
#  '2008-03-17': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2008-03-19': {'edit_count': 4,
#   'sentiment': -0.4726947695016861,
#   'neg_sentiment': 0.75},
#  '2008-03-27': {'edit_count': 1,
#   'sentiment': -0.9994052648544312,
#   'neg_sentiment': 1.0},
#  '2008-04-01': {'edit_count': 1,
#   'sentiment': -0.9760538339614868,
#   'neg_sentiment': 1.0},
#  '2008-04-12': {'edit_count': 1,
#   'sentiment': -0.9927478432655334,
#   'neg_sentiment': 1.0},
#  '2008-04-14': {'edit_count': 1,
#   'sentiment': -0.8911853432655334,
#   'neg_sentiment': 1.0},
#  '2008-04-15': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2008-04-18': {'edit_count': 1,
#   'sentiment': -0.782187283039093,
#   'neg_sentiment': 1.0},
#  '2008-04-21': {'edit_count': 2,
#   'sentiment': 0.903205394744873,
#   'neg_sentiment': 0.0},
#  '2008-04-23': {'edit_count': 1,
#   'sentiment': -0.9993372559547424,
#   'neg_sentiment': 1.0},
#  '2008-04-25': {'edit_count': 12,
#   'sentiment': 0.779727429151535,
#   'neg_sentiment': 0.08333333333333333},
#  '2008-04-26': {'edit_count': 28,
#   'sentiment': -0.1253115619931902,
#   'neg_sentiment': 0.5357142857142857},
#  '2008-04-27': {'edit_count': 3,
#   'sentiment': -0.34295103947321576,
#   'neg_sentiment': 0.6666666666666666},
#  '2008-04-28': {'edit_count': 2,
#   'sentiment': -0.975531816482544,
#   'neg_sentiment': 1.0},
#  '2008-05-02': {'edit_count': 1,
#   'sentiment': -0.9965015649795532,
#   'neg_sentiment': 1.0},
#  '2008-05-03': {'edit_count': 1,
#   'sentiment': 0.994619607925415,
#   'neg_sentiment': 0.0},
#  '2008-05-04': {'edit_count': 4,
#   'sentiment': 0.8902208358049393,
#   'neg_sentiment': 0.0},
#  '2008-05-05': {'edit_count': 2,
#   'sentiment': -0.013352692127227783,
#   'neg_sentiment': 0.5},
#  '2008-05-13': {'edit_count': 2,
#   'sentiment': -0.9979097843170166,
#   'neg_sentiment': 1.0},
#  '2008-05-18': {'edit_count': 1,
#   'sentiment': -0.997188150882721,
#   'neg_sentiment': 1.0},
#  '2008-05-21': {'edit_count': 1,
#   'sentiment': 0.9300209879875183,
#   'neg_sentiment': 0.0},
#  '2008-05-23': {'edit_count': 2,
#   'sentiment': 0.9010385274887085,
#   'neg_sentiment': 0.0},
#  '2008-05-25': {'edit_count': 1,
#   'sentiment': 0.7716571688652039,
#   'neg_sentiment': 0.0},
#  '2008-05-26': {'edit_count': 1,
#   'sentiment': 0.9300209879875183,
#   'neg_sentiment': 0.0},
#  '2008-05-30': {'edit_count': 2,
#   'sentiment': -0.9894636571407318,
#   'neg_sentiment': 1.0},
#  '2008-05-31': {'edit_count': 1,
#   'sentiment': -0.509772777557373,
#   'neg_sentiment': 1.0},
#  '2008-06-03': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2008-06-04': {'edit_count': 3,
#   'sentiment': 0.27500083049138385,
#   'neg_sentiment': 0.3333333333333333},
#  '2008-06-14': {'edit_count': 4,
#   'sentiment': -0.06237493455410004,
#   'neg_sentiment': 0.5},
#  '2008-06-15': {'edit_count': 1,
#   'sentiment': -0.996968686580658,
#   'neg_sentiment': 1.0},
#  '2008-06-16': {'edit_count': 1,
#   'sentiment': -0.9985347986221313,
#   'neg_sentiment': 1.0},
#  '2008-06-17': {'edit_count': 1,
#   'sentiment': -0.9943262934684753,
#   'neg_sentiment': 1.0},
#  '2008-06-20': {'edit_count': 4,
#   'sentiment': -0.9576481878757477,
#   'neg_sentiment': 1.0},
#  '2008-07-03': {'edit_count': 1,
#   'sentiment': 0.9995884299278259,
#   'neg_sentiment': 0.0},
#  '2008-07-08': {'edit_count': 1,
#   'sentiment': 0.9510911703109741,
#   'neg_sentiment': 0.0},
#  '2008-07-10': {'edit_count': 2,
#   'sentiment': 0.7716571688652039,
#   'neg_sentiment': 0.0},
#  '2008-07-11': {'edit_count': 1,
#   'sentiment': -0.6380744576454163,
#   'neg_sentiment': 1.0},
#  '2008-07-16': {'edit_count': 2,
#   'sentiment': 0.9510911703109741,
#   'neg_sentiment': 0.0},
#  '2008-08-05': {'edit_count': 1,
#   'sentiment': -0.9964178800582886,
#   'neg_sentiment': 1.0},
#  '2008-08-09': {'edit_count': 1,
#   'sentiment': -0.8911853432655334,
#   'neg_sentiment': 1.0},
#  '2008-08-13': {'edit_count': 1,
#   'sentiment': -0.985237181186676,
#   'neg_sentiment': 1.0},
#  '2008-08-14': {'edit_count': 1,
#   'sentiment': 0.8504335284233093,
#   'neg_sentiment': 0.0},
#  '2008-08-21': {'edit_count': 1,
#   'sentiment': 0.9702188372612,
#   'neg_sentiment': 0.0},
#  '2008-08-28': {'edit_count': 1,
#   'sentiment': -0.8911853432655334,
#   'neg_sentiment': 1.0},
#  '2008-09-02': {'edit_count': 1,
#   'sentiment': -0.997136116027832,
#   'neg_sentiment': 1.0},
#  '2008-09-03': {'edit_count': 5,
#   'sentiment': 0.9331140041351318,
#   'neg_sentiment': 0.0},
#  '2008-09-04': {'edit_count': 4,
#   'sentiment': 0.3118700087070465,
#   'neg_sentiment': 0.25},
#  '2008-09-06': {'edit_count': 3,
#   'sentiment': -0.32696102062861127,
#   'neg_sentiment': 0.6666666666666666},
#  '2008-09-09': {'edit_count': 2,
#   'sentiment': -0.1256769597530365,
#   'neg_sentiment': 0.5},
#  '2008-09-11': {'edit_count': 4,
#   'sentiment': -0.491129070520401,
#   'neg_sentiment': 0.75},
#  '2008-09-15': {'edit_count': 2,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2008-09-18': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2008-09-22': {'edit_count': 1,
#   'sentiment': -0.999804675579071,
#   'neg_sentiment': 1.0},
#  '2008-09-24': {'edit_count': 1,
#   'sentiment': -0.9942771792411804,
#   'neg_sentiment': 1.0},
#  '2008-09-26': {'edit_count': 1,
#   'sentiment': -0.6418957114219666,
#   'neg_sentiment': 1.0},
#  '2008-09-30': {'edit_count': 1,
#   'sentiment': -0.9134532809257507,
#   'neg_sentiment': 1.0},
#  '2008-10-04': {'edit_count': 2,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2008-10-10': {'edit_count': 4,
#   'sentiment': -0.9862277209758759,
#   'neg_sentiment': 1.0},
#  '2008-10-27': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2008-10-28': {'edit_count': 1,
#   'sentiment': -0.9930809140205383,
#   'neg_sentiment': 1.0},
#  '2008-11-09': {'edit_count': 1,
#   'sentiment': 0.9702188372612,
#   'neg_sentiment': 0.0},
#  '2008-11-10': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2008-11-11': {'edit_count': 4,
#   'sentiment': -0.5601652711629868,
#   'neg_sentiment': 0.75},
#  '2008-11-13': {'edit_count': 4,
#   'sentiment': 0.4486325830221176,
#   'neg_sentiment': 0.25},
#  '2008-11-16': {'edit_count': 1,
#   'sentiment': 0.9993853569030762,
#   'neg_sentiment': 0.0},
#  '2008-11-17': {'edit_count': 1,
#   'sentiment': -0.989569902420044,
#   'neg_sentiment': 1.0},
#  '2008-11-21': {'edit_count': 2,
#   'sentiment': -0.9986005425453186,
#   'neg_sentiment': 1.0},
#  '2008-11-22': {'edit_count': 1,
#   'sentiment': 0.9993853569030762,
#   'neg_sentiment': 0.0},
#  '2008-11-23': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2008-11-28': {'edit_count': 1,
#   'sentiment': -0.9975591897964478,
#   'neg_sentiment': 1.0},
#  '2008-12-02': {'edit_count': 4,
#   'sentiment': -0.40332749485969543,
#   'neg_sentiment': 0.75},
#  '2008-12-10': {'edit_count': 1,
#   'sentiment': 0.9624136090278625,
#   'neg_sentiment': 0.0},
#  '2008-12-13': {'edit_count': 1,
#   'sentiment': 0.9993853569030762,
#   'neg_sentiment': 0.0},
#  '2008-12-14': {'edit_count': 4,
#   'sentiment': 0.026237234473228455,
#   'neg_sentiment': 0.5},
#  '2008-12-20': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2008-12-21': {'edit_count': 1,
#   'sentiment': 0.8509858846664429,
#   'neg_sentiment': 0.0},
#  '2008-12-23': {'edit_count': 4,
#   'sentiment': 0.4185541421175003,
#   'neg_sentiment': 0.25},
#  '2008-12-24': {'edit_count': 2,
#   'sentiment': 0.7598890364170074,
#   'neg_sentiment': 0.0},
#  '2008-12-26': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2008-12-27': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-01-12': {'edit_count': 2,
#   'sentiment': 0.9368510544300079,
#   'neg_sentiment': 0.0},
#  '2009-01-14': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-01-15': {'edit_count': 2,
#   'sentiment': -0.9987945556640625,
#   'neg_sentiment': 1.0},
#  '2009-01-23': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2009-01-25': {'edit_count': 1,
#   'sentiment': 0.9588318467140198,
#   'neg_sentiment': 0.0},
#  '2009-01-30': {'edit_count': 2,
#   'sentiment': -0.011574536561965942,
#   'neg_sentiment': 0.5},
#  '2009-02-05': {'edit_count': 2,
#   'sentiment': 0.7169199287891388,
#   'neg_sentiment': 0.0},
#  '2009-02-18': {'edit_count': 1,
#   'sentiment': -0.9797382354736328,
#   'neg_sentiment': 1.0},
#  '2009-02-19': {'edit_count': 3,
#   'sentiment': 0.4406859874725342,
#   'neg_sentiment': 0.3333333333333333},
#  '2009-02-28': {'edit_count': 1,
#   'sentiment': 0.8504335284233093,
#   'neg_sentiment': 0.0},
#  '2009-03-08': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2009-03-11': {'edit_count': 3,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2009-03-20': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-03-25': {'edit_count': 1,
#   'sentiment': -0.9884822368621826,
#   'neg_sentiment': 1.0},
#  '2009-03-27': {'edit_count': 1,
#   'sentiment': 0.8337069749832153,
#   'neg_sentiment': 0.0},
#  '2009-03-28': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-04-02': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2009-04-09': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2009-04-12': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-04-21': {'edit_count': 1,
#   'sentiment': -0.9934084415435791,
#   'neg_sentiment': 1.0},
#  '2009-04-24': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2009-05-03': {'edit_count': 1,
#   'sentiment': 0.9761273264884949,
#   'neg_sentiment': 0.0},
#  '2009-05-14': {'edit_count': 1,
#   'sentiment': -0.9915114045143127,
#   'neg_sentiment': 1.0},
#  '2009-05-16': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-05-18': {'edit_count': 4,
#   'sentiment': 0.9702188372612,
#   'neg_sentiment': 0.0},
#  '2009-05-21': {'edit_count': 4,
#   'sentiment': -0.9955294579267502,
#   'neg_sentiment': 1.0},
#  '2009-05-24': {'edit_count': 2,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2009-05-26': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-06-02': {'edit_count': 1,
#   'sentiment': -0.989569902420044,
#   'neg_sentiment': 1.0},
#  '2009-06-04': {'edit_count': 1,
#   'sentiment': 0.9510911703109741,
#   'neg_sentiment': 0.0},
#  '2009-06-13': {'edit_count': 1,
#   'sentiment': -0.9969940185546875,
#   'neg_sentiment': 1.0},
#  '2009-06-17': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-06-23': {'edit_count': 2,
#   'sentiment': 0.9702188372612,
#   'neg_sentiment': 0.0},
#  '2009-06-29': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-07-01': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2009-07-28': {'edit_count': 1,
#   'sentiment': 0.8504335284233093,
#   'neg_sentiment': 0.0},
#  '2009-07-31': {'edit_count': 1,
#   'sentiment': 0.9957593083381653,
#   'neg_sentiment': 0.0},
#  '2009-08-09': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-08-17': {'edit_count': 3,
#   'sentiment': 0.9034832715988159,
#   'neg_sentiment': 0.0},
#  '2009-08-25': {'edit_count': 1,
#   'sentiment': 0.8836537599563599,
#   'neg_sentiment': 0.0},
#  '2009-08-26': {'edit_count': 1,
#   'sentiment': -0.9974092841148376,
#   'neg_sentiment': 1.0},
#  '2009-08-28': {'edit_count': 1,
#   'sentiment': -0.9991600513458252,
#   'neg_sentiment': 1.0},
#  '2009-08-29': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2009-09-07': {'edit_count': 2,
#   'sentiment': -0.0005414485931396484,
#   'neg_sentiment': 0.5},
#  '2009-09-20': {'edit_count': 2,
#   'sentiment': -0.056678593158721924,
#   'neg_sentiment': 0.5},
#  '2009-10-04': {'edit_count': 1,
#   'sentiment': 0.9702188372612,
#   'neg_sentiment': 0.0},
#  '2009-10-16': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2009-10-24': {'edit_count': 1,
#   'sentiment': -0.9597656726837158,
#   'neg_sentiment': 1.0},
#  '2009-10-26': {'edit_count': 1,
#   'sentiment': 0.8069125413894653,
#   'neg_sentiment': 0.0},
#  '2009-11-01': {'edit_count': 2,
#   'sentiment': -0.0175035297870636,
#   'neg_sentiment': 0.5},
#  '2009-11-02': {'edit_count': 1,
#   'sentiment': -0.9977537989616394,
#   'neg_sentiment': 1.0},
#  '2009-11-04': {'edit_count': 2,
#   'sentiment': -0.9960901141166687,
#   'neg_sentiment': 1.0},
#  '2009-11-10': {'edit_count': 2,
#   'sentiment': 0.7598890364170074,
#   'neg_sentiment': 0.0},
#  '2009-11-11': {'edit_count': 2,
#   'sentiment': 0.9827697277069092,
#   'neg_sentiment': 0.0},
#  '2009-11-12': {'edit_count': 1,
#   'sentiment': -0.9979768395423889,
#   'neg_sentiment': 1.0},
#  '2009-12-01': {'edit_count': 1,
#   'sentiment': -0.9978552460670471,
#   'neg_sentiment': 1.0},
#  '2009-12-02': {'edit_count': 2,
#   'sentiment': -0.9993101060390472,
#   'neg_sentiment': 1.0},
#  '2009-12-04': {'edit_count': 2,
#   'sentiment': -0.1236368715763092,
#   'neg_sentiment': 0.5},
#  '2009-12-14': {'edit_count': 1,
#   'sentiment': -0.9880978465080261,
#   'neg_sentiment': 1.0},
#  '2009-12-18': {'edit_count': 1,
#   'sentiment': 0.7576072216033936,
#   'neg_sentiment': 0.0},
#  '2009-12-23': {'edit_count': 1,
#   'sentiment': 0.9034832715988159,
#   'neg_sentiment': 0.0},
#  '2009-12-25': {'edit_count': 1,
#   'sentiment': 0.9300209879875183,
#   'neg_sentiment': 0.0},
#  '2009-12-26': {'edit_count': 5,
#   'sentiment': 0.10238944292068482,
#   'neg_sentiment': 0.4},
#  '2009-12-27': {'edit_count': 2,
#   'sentiment': -0.032188087701797485,
#   'neg_sentiment': 0.5},
#  '2009-12-29': {'edit_count': 4,
#   'sentiment': -0.024477362632751465,
#   'neg_sentiment': 0.5},
#  '2009-12-30': {'edit_count': 2,
#   'sentiment': -0.032188087701797485,
#   'neg_sentiment': 0.5},
#  '2009-12-31': {'edit_count': 2,
#   'sentiment': -0.03447607159614563,
#   'neg_sentiment': 0.5},
#  '2010-01-09': {'edit_count': 3,
#   'sentiment': 0.28225936492284137,
#   'neg_sentiment': 0.3333333333333333},
#  '2010-01-13': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-01-14': {'edit_count': 1,
#   'sentiment': -0.9956610798835754,
#   'neg_sentiment': 1.0},
#  '2010-01-17': {'edit_count': 2,
#   'sentiment': -0.05074411630630493,
#   'neg_sentiment': 0.5},
#  '2010-01-18': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2010-01-22': {'edit_count': 1,
#   'sentiment': -0.9994433522224426,
#   'neg_sentiment': 1.0},
#  '2010-02-02': {'edit_count': 2,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2010-02-03': {'edit_count': 4,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2010-02-05': {'edit_count': 3,
#   'sentiment': -0.4144533673922221,
#   'neg_sentiment': 0.6666666666666666},
#  '2010-02-06': {'edit_count': 1,
#   'sentiment': 0.8504335284233093,
#   'neg_sentiment': 0.0},
#  '2010-02-08': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-02-17': {'edit_count': 1,
#   'sentiment': -0.9977795481681824,
#   'neg_sentiment': 1.0},
#  '2010-02-19': {'edit_count': 2,
#   'sentiment': -0.12323042750358582,
#   'neg_sentiment': 0.5},
#  '2010-02-20': {'edit_count': 1,
#   'sentiment': -0.993436336517334,
#   'neg_sentiment': 1.0},
#  '2010-02-23': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-02-26': {'edit_count': 1,
#   'sentiment': -0.9984439015388489,
#   'neg_sentiment': 1.0},
#  '2010-03-03': {'edit_count': 1,
#   'sentiment': 0.9624136090278625,
#   'neg_sentiment': 0.0},
#  '2010-03-04': {'edit_count': 4,
#   'sentiment': 0.4334579110145569,
#   'neg_sentiment': 0.25},
#  '2010-03-05': {'edit_count': 1,
#   'sentiment': -0.9946689009666443,
#   'neg_sentiment': 1.0},
#  '2010-03-06': {'edit_count': 2,
#   'sentiment': -0.1233784556388855,
#   'neg_sentiment': 0.5},
#  '2010-03-10': {'edit_count': 2,
#   'sentiment': -0.9985627830028534,
#   'neg_sentiment': 1.0},
#  '2010-03-12': {'edit_count': 1,
#   'sentiment': -0.5764923095703125,
#   'neg_sentiment': 1.0},
#  '2010-03-14': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2010-03-26': {'edit_count': 2,
#   'sentiment': 0.0016122162342071533,
#   'neg_sentiment': 0.5},
#  '2010-03-29': {'edit_count': 2,
#   'sentiment': -0.9770167171955109,
#   'neg_sentiment': 1.0},
#  '2010-04-03': {'edit_count': 3,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2010-04-10': {'edit_count': 10,
#   'sentiment': -0.07320552468299865,
#   'neg_sentiment': 0.5},
#  '2010-04-13': {'edit_count': 1,
#   'sentiment': -0.9947975873947144,
#   'neg_sentiment': 1.0},
#  '2010-04-25': {'edit_count': 2,
#   'sentiment': -0.12128254771232605,
#   'neg_sentiment': 0.5},
#  '2010-04-30': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2010-05-04': {'edit_count': 1,
#   'sentiment': -0.9924951791763306,
#   'neg_sentiment': 1.0},
#  '2010-05-06': {'edit_count': 2,
#   'sentiment': -0.12036433815956116,
#   'neg_sentiment': 0.5},
#  '2010-05-09': {'edit_count': 1,
#   'sentiment': -0.9997616410255432,
#   'neg_sentiment': 1.0},
#  '2010-05-12': {'edit_count': 3,
#   'sentiment': -0.9381102522214254,
#   'neg_sentiment': 1.0},
#  '2010-05-13': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-05-14': {'edit_count': 4,
#   'sentiment': -0.5511609464883804,
#   'neg_sentiment': 0.75},
#  '2010-05-15': {'edit_count': 2,
#   'sentiment': -0.9405386745929718,
#   'neg_sentiment': 1.0},
#  '2010-05-18': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2010-05-24': {'edit_count': 2,
#   'sentiment': -0.010280460119247437,
#   'neg_sentiment': 0.5},
#  '2010-06-04': {'edit_count': 1,
#   'sentiment': 0.7716571688652039,
#   'neg_sentiment': 0.0},
#  '2010-06-07': {'edit_count': 1,
#   'sentiment': -0.9985665678977966,
#   'neg_sentiment': 1.0},
#  '2010-06-18': {'edit_count': 1,
#   'sentiment': -0.9890751838684082,
#   'neg_sentiment': 1.0},
#  '2010-06-21': {'edit_count': 1,
#   'sentiment': 0.9989245533943176,
#   'neg_sentiment': 0.0},
#  '2010-06-29': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-07-18': {'edit_count': 1,
#   'sentiment': 0.5820044279098511,
#   'neg_sentiment': 0.0},
#  '2010-07-19': {'edit_count': 1,
#   'sentiment': 0.9702188372612,
#   'neg_sentiment': 0.0},
#  '2010-07-20': {'edit_count': 1,
#   'sentiment': -0.9989136457443237,
#   'neg_sentiment': 1.0},
#  '2010-08-14': {'edit_count': 1,
#   'sentiment': -0.9974581599235535,
#   'neg_sentiment': 1.0},
#  '2010-08-23': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-08-25': {'edit_count': 1,
#   'sentiment': 0.9960460066795349,
#   'neg_sentiment': 0.0},
#  '2010-08-29': {'edit_count': 2,
#   'sentiment': -0.04615592956542969,
#   'neg_sentiment': 0.5},
#  '2010-09-02': {'edit_count': 1,
#   'sentiment': -0.9926718473434448,
#   'neg_sentiment': 1.0},
#  '2010-09-03': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-09-07': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2010-09-15': {'edit_count': 5,
#   'sentiment': 0.11308134794235229,
#   'neg_sentiment': 0.4},
#  '2010-09-20': {'edit_count': 1,
#   'sentiment': -0.5711972713470459,
#   'neg_sentiment': 1.0},
#  '2010-09-24': {'edit_count': 1,
#   'sentiment': -0.9985296726226807,
#   'neg_sentiment': 1.0},
#  '2010-09-25': {'edit_count': 2,
#   'sentiment': -0.12339073419570923,
#   'neg_sentiment': 0.5},
#  '2010-09-26': {'edit_count': 1,
#   'sentiment': -0.9845376014709473,
#   'neg_sentiment': 1.0},
#  '2010-10-01': {'edit_count': 1,
#   'sentiment': -0.9989218711853027,
#   'neg_sentiment': 1.0},
#  '2010-10-02': {'edit_count': 1,
#   'sentiment': 0.9702188372612,
#   'neg_sentiment': 0.0},
#  '2010-10-04': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-10-05': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-10-17': {'edit_count': 6,
#   'sentiment': 0.5326720873514811,
#   'neg_sentiment': 0.16666666666666666},
#  '2010-10-24': {'edit_count': 2,
#   'sentiment': -0.004098802804946899,
#   'neg_sentiment': 0.5},
#  '2010-10-29': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2010-10-30': {'edit_count': 3,
#   'sentiment': -0.3994699716567993,
#   'neg_sentiment': 0.6666666666666666},
#  '2010-11-06': {'edit_count': 2,
#   'sentiment': 0.9034832715988159,
#   'neg_sentiment': 0.0},
#  '2010-11-07': {'edit_count': 1,
#   'sentiment': -0.9429419040679932,
#   'neg_sentiment': 1.0},
#  '2010-11-08': {'edit_count': 2,
#   'sentiment': -0.12045708298683167,
#   'neg_sentiment': 0.5},
#  '2010-11-15': {'edit_count': 1,
#   'sentiment': 0.694173276424408,
#   'neg_sentiment': 0.0},
#  '2010-11-23': {'edit_count': 1,
#   'sentiment': -0.9892270565032959,
#   'neg_sentiment': 1.0},
#  '2010-12-03': {'edit_count': 6,
#   'sentiment': 0.5520756045977274,
#   'neg_sentiment': 0.16666666666666666},
#  '2010-12-09': {'edit_count': 2,
#   'sentiment': 0.9034832715988159,
#   'neg_sentiment': 0.0},
#  '2010-12-11': {'edit_count': 2,
#   'sentiment': -0.9328368604183197,
#   'neg_sentiment': 1.0},
#  '2010-12-18': {'edit_count': 4,
#   'sentiment': 0.7716571688652039,
#   'neg_sentiment': 0.0},
#  '2010-12-19': {'edit_count': 1,
#   'sentiment': 0.7716571688652039,
#   'neg_sentiment': 0.0},
#  '2010-12-27': {'edit_count': 1,
#   'sentiment': 0.9300209879875183,
#   'neg_sentiment': 0.0},
#  '2011-01-07': {'edit_count': 3,
#   'sentiment': -0.35575634241104126,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-01-08': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-01-09': {'edit_count': 3,
#   'sentiment': 0.8615069389343262,
#   'neg_sentiment': 0.0},
#  '2011-01-10': {'edit_count': 2,
#   'sentiment': 0.8836537599563599,
#   'neg_sentiment': 0.0},
#  '2011-01-23': {'edit_count': 9,
#   'sentiment': 0.08075737290912205,
#   'neg_sentiment': 0.4444444444444444},
#  '2011-01-28': {'edit_count': 1,
#   'sentiment': -0.9986995458602905,
#   'neg_sentiment': 1.0},
#  '2011-02-11': {'edit_count': 3,
#   'sentiment': 0.2508665720621745,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-02-17': {'edit_count': 1,
#   'sentiment': -0.6183797121047974,
#   'neg_sentiment': 1.0},
#  '2011-03-21': {'edit_count': 1,
#   'sentiment': 0.9702188372612,
#   'neg_sentiment': 0.0},
#  '2011-03-29': {'edit_count': 1,
#   'sentiment': 0.8475968241691589,
#   'neg_sentiment': 0.0},
#  '2011-04-05': {'edit_count': 1,
#   'sentiment': -0.9624337553977966,
#   'neg_sentiment': 1.0},
#  '2011-04-22': {'edit_count': 1,
#   'sentiment': 0.9852107167243958,
#   'neg_sentiment': 0.0},
#  '2011-04-28': {'edit_count': 1,
#   'sentiment': -0.9831970930099487,
#   'neg_sentiment': 1.0},
#  '2011-04-29': {'edit_count': 3,
#   'sentiment': -0.3770823081334432,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-05-03': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2011-05-04': {'edit_count': 1,
#   'sentiment': 0.9973599314689636,
#   'neg_sentiment': 0.0},
#  '2011-05-06': {'edit_count': 1,
#   'sentiment': -0.9985620379447937,
#   'neg_sentiment': 1.0},
#  '2011-05-16': {'edit_count': 1,
#   'sentiment': -0.9973286390304565,
#   'neg_sentiment': 1.0},
#  '2011-05-21': {'edit_count': 1,
#   'sentiment': 0.7716571688652039,
#   'neg_sentiment': 0.0},
#  '2011-05-25': {'edit_count': 1,
#   'sentiment': 0.9992089867591858,
#   'neg_sentiment': 0.0},
#  '2011-06-26': {'edit_count': 1,
#   'sentiment': 0.9510911703109741,
#   'neg_sentiment': 0.0},
#  '2011-06-27': {'edit_count': 1,
#   'sentiment': -0.9985705614089966,
#   'neg_sentiment': 1.0},
#  '2011-06-29': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-07-02': {'edit_count': 1,
#   'sentiment': -0.955452024936676,
#   'neg_sentiment': 1.0},
#  '2011-07-03': {'edit_count': 1,
#   'sentiment': -0.995415449142456,
#   'neg_sentiment': 1.0},
#  '2011-07-04': {'edit_count': 9,
#   'sentiment': -0.16731984747780693,
#   'neg_sentiment': 0.5555555555555556},
#  '2011-07-05': {'edit_count': 2,
#   'sentiment': -0.7587687075138092,
#   'neg_sentiment': 1.0},
#  '2011-07-06': {'edit_count': 1,
#   'sentiment': -0.99354088306427,
#   'neg_sentiment': 1.0},
#  '2011-07-07': {'edit_count': 1,
#   'sentiment': 0.9702188372612,
#   'neg_sentiment': 0.0},
#  '2011-07-10': {'edit_count': 4,
#   'sentiment': 0.37072888016700745,
#   'neg_sentiment': 0.25},
#  '2011-07-11': {'edit_count': 2,
#   'sentiment': -0.9905975461006165,
#   'neg_sentiment': 1.0},
#  '2011-07-12': {'edit_count': 2,
#   'sentiment': 0.007898420095443726,
#   'neg_sentiment': 0.5},
#  '2011-08-01': {'edit_count': 1,
#   'sentiment': -0.9948602318763733,
#   'neg_sentiment': 1.0},
#  '2011-08-10': {'edit_count': 12,
#   'sentiment': -0.6405950436989466,
#   'neg_sentiment': 0.8333333333333334},
#  '2011-08-17': {'edit_count': 3,
#   'sentiment': 0.19970198472340903,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-09-03': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-09-22': {'edit_count': 3,
#   'sentiment': -0.4130147298177083,
#   'neg_sentiment': 0.6666666666666666},
#  '2011-09-28': {'edit_count': 4,
#   'sentiment': 0.45553719997406006,
#   'neg_sentiment': 0.25},
#  '2011-10-03': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-10-11': {'edit_count': 2,
#   'sentiment': -0.05410072207450867,
#   'neg_sentiment': 0.5},
#  '2011-10-27': {'edit_count': 1,
#   'sentiment': -0.8314360976219177,
#   'neg_sentiment': 1.0},
#  '2011-10-31': {'edit_count': 1,
#   'sentiment': 0.9300209879875183,
#   'neg_sentiment': 0.0},
#  '2011-11-03': {'edit_count': 2,
#   'sentiment': -0.03417384624481201,
#   'neg_sentiment': 0.5},
#  '2011-11-05': {'edit_count': 2,
#   'sentiment': -0.02352297306060791,
#   'neg_sentiment': 0.5},
#  '2011-11-06': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-11-07': {'edit_count': 2,
#   'sentiment': -0.034508973360061646,
#   'neg_sentiment': 0.5},
#  '2011-11-08': {'edit_count': 1,
#   'sentiment': -0.6183797121047974,
#   'neg_sentiment': 1.0},
#  '2011-11-20': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-11-21': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-11-24': {'edit_count': 1,
#   'sentiment': -0.9979501366615295,
#   'neg_sentiment': 1.0},
#  '2011-11-28': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2011-11-29': {'edit_count': 1,
#   'sentiment': 0.9510911703109741,
#   'neg_sentiment': 0.0},
#  '2011-12-02': {'edit_count': 3,
#   'sentiment': 0.3259965380032857,
#   'neg_sentiment': 0.3333333333333333},
#  '2011-12-22': {'edit_count': 1,
#   'sentiment': -0.999366819858551,
#   'neg_sentiment': 1.0},
#  '2012-01-17': {'edit_count': 1,
#   'sentiment': -0.9985318183898926,
#   'neg_sentiment': 1.0},
#  '2012-02-06': {'edit_count': 1,
#   'sentiment': -0.9778894782066345,
#   'neg_sentiment': 1.0},
#  '2012-02-17': {'edit_count': 2,
#   'sentiment': 0.9330793023109436,
#   'neg_sentiment': 0.0},
#  '2012-02-23': {'edit_count': 1,
#   'sentiment': -0.9610918760299683,
#   'neg_sentiment': 1.0},
#  '2012-02-26': {'edit_count': 1,
#   'sentiment': -0.9880204796791077,
#   'neg_sentiment': 1.0},
#  '2012-03-01': {'edit_count': 3,
#   'sentiment': 0.2783051331837972,
#   'neg_sentiment': 0.3333333333333333},
#  '2012-03-14': {'edit_count': 4,
#   'sentiment': 0.05701850354671478,
#   'neg_sentiment': 0.5},
#  '2012-03-17': {'edit_count': 4,
#   'sentiment': -0.5220326036214828,
#   'neg_sentiment': 0.75},
#  '2012-03-26': {'edit_count': 1,
#   'sentiment': 0.9969569444656372,
#   'neg_sentiment': 0.0},
#  '2012-03-31': {'edit_count': 1,
#   'sentiment': 0.9020455479621887,
#   'neg_sentiment': 0.0},
#  '2012-04-01': {'edit_count': 1,
# ...
#   'sentiment': -0.9978206157684326,
#   'neg_sentiment': 1.0},
#  '2017-11-01': {'edit_count': 1,
#   'sentiment': -0.9985438585281372,
#   'neg_sentiment': 1.0},
#  '2017-11-03': {'edit_count': 1,
#   'sentiment': -0.9990932941436768,
#   'neg_sentiment': 1.0},
#  '2017-12-03': {'edit_count': 1,
#   'sentiment': -0.9989674091339111,
#   'neg_sentiment': 1.0},
#  '2017-12-06': {'edit_count': 1,
#   'sentiment': 0.9996240139007568,
#   'neg_sentiment': 0.0},
#  '2017-12-15': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2017-12-27': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2018-01-02': {'edit_count': 1,
#   'sentiment': -0.9991059899330139,
#   'neg_sentiment': 1.0},
#  '2018-01-04': {'edit_count': 1,
#   'sentiment': -0.9830543398857117,
#   'neg_sentiment': 1.0},
#  '2018-01-21': {'edit_count': 1,
#   'sentiment': -0.9924930930137634,
#   'neg_sentiment': 1.0},
#  '2018-02-04': {'edit_count': 3,
#   'sentiment': -0.30035459995269775,
#   'neg_sentiment': 0.6666666666666666},
#  '2018-02-09': {'edit_count': 1,
#   'sentiment': -0.6310243010520935,
#   'neg_sentiment': 1.0},
#  '2018-02-10': {'edit_count': 1,
#   'sentiment': 0.9921258687973022,
#   'neg_sentiment': 0.0},
#  '2018-02-20': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2018-03-09': {'edit_count': 1,
#   'sentiment': -0.9553443193435669,
#   'neg_sentiment': 1.0},
#  '2018-03-12': {'edit_count': 2,
#   'sentiment': -0.12367445230484009,
#   'neg_sentiment': 0.5},
#  '2018-03-17': {'edit_count': 1,
#   'sentiment': 0.8836537599563599,
#   'neg_sentiment': 0.0},
#  '2018-03-25': {'edit_count': 2,
#   'sentiment': 0.8739060759544373,
#   'neg_sentiment': 0.0},
#  '2018-04-19': {'edit_count': 1,
#   'sentiment': 0.9839890599250793,
#   'neg_sentiment': 0.0},
#  '2018-04-24': {'edit_count': 5,
#   'sentiment': 0.49836828708648684,
#   'neg_sentiment': 0.2},
#  '2018-04-30': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2018-05-01': {'edit_count': 2,
#   'sentiment': -0.8264530003070831,
#   'neg_sentiment': 1.0},
#  '2018-05-02': {'edit_count': 2,
#   'sentiment': -0.03199291229248047,
#   'neg_sentiment': 0.5},
#  '2018-05-15': {'edit_count': 1,
#   'sentiment': -0.998304009437561,
#   'neg_sentiment': 1.0},
#  '2018-05-16': {'edit_count': 1,
#   'sentiment': 0.981187641620636,
#   'neg_sentiment': 0.0},
#  '2018-05-18': {'edit_count': 2,
#   'sentiment': 0.9276388883590698,
#   'neg_sentiment': 0.0},
#  '2018-05-23': {'edit_count': 1,
#   'sentiment': -0.9959905743598938,
#   'neg_sentiment': 1.0},
#  '2018-05-26': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2018-05-28': {'edit_count': 3,
#   'sentiment': 0.1660253405570984,
#   'neg_sentiment': 0.3333333333333333},
#  '2018-06-24': {'edit_count': 1,
#   'sentiment': -0.9987764954566956,
#   'neg_sentiment': 1.0},
#  '2018-07-30': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2018-07-31': {'edit_count': 2,
#   'sentiment': 0.872098833322525,
#   'neg_sentiment': 0.0},
#  '2018-08-03': {'edit_count': 1,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2018-08-10': {'edit_count': 1,
#   'sentiment': -0.9960476756095886,
#   'neg_sentiment': 1.0},
#  '2018-08-23': {'edit_count': 4,
#   'sentiment': 0.8390709459781647,
#   'neg_sentiment': 0.0},
#  '2018-08-26': {'edit_count': 1,
#   'sentiment': -0.9865390658378601,
#   'neg_sentiment': 1.0},
#  '2018-09-08': {'edit_count': 1,
#   'sentiment': -0.9986039996147156,
#   'neg_sentiment': 1.0},
#  '2018-11-09': {'edit_count': 1,
#   'sentiment': 0.9637662768363953,
#   'neg_sentiment': 0.0},
#  '2018-11-10': {'edit_count': 1,
#   'sentiment': 0.9763814806938171,
#   'neg_sentiment': 0.0},
#  '2018-11-16': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2018-12-09': {'edit_count': 2,
#   'sentiment': -0.02367505431175232,
#   'neg_sentiment': 0.5},
#  '2018-12-24': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2019-01-30': {'edit_count': 4,
#   'sentiment': -0.11947672069072723,
#   'neg_sentiment': 0.5},
#  '2019-02-06': {'edit_count': 1,
#   'sentiment': 0.966778576374054,
#   'neg_sentiment': 0.0},
#  '2019-02-13': {'edit_count': 1,
#   'sentiment': -0.9688282608985901,
#   'neg_sentiment': 1.0},
#  '2019-02-25': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2019-03-26': {'edit_count': 1,
#   'sentiment': 0.9958899617195129,
#   'neg_sentiment': 0.0},
#  '2019-04-10': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2019-04-12': {'edit_count': 1,
#   'sentiment': -0.9988037347793579,
#   'neg_sentiment': 1.0},
#  '2019-04-16': {'edit_count': 1,
#   'sentiment': 0.9034832715988159,
#   'neg_sentiment': 0.0},
#  '2019-05-22': {'edit_count': 2,
#   'sentiment': -0.00628054141998291,
#   'neg_sentiment': 0.5},
#  '2019-05-23': {'edit_count': 2,
#   'sentiment': -0.12000793218612671,
#   'neg_sentiment': 0.5},
#  '2019-06-06': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2019-06-15': {'edit_count': 4,
#   'sentiment': 0.7935959249734879,
#   'neg_sentiment': 0.0},
#  '2019-07-03': {'edit_count': 2,
#   'sentiment': -0.14286717772483826,
#   'neg_sentiment': 0.5},
#  '2019-07-14': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2019-09-06': {'edit_count': 3,
#   'sentiment': -0.2558495004971822,
#   'neg_sentiment': 0.6666666666666666},
#  '2019-09-08': {'edit_count': 2,
#   'sentiment': 0.8557834625244141,
#   'neg_sentiment': 0.0},
#  '2019-09-20': {'edit_count': 1,
#   'sentiment': -0.9993808269500732,
#   'neg_sentiment': 1.0},
#  '2019-10-24': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2019-10-25': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2019-11-23': {'edit_count': 1,
#   'sentiment': 0.9791170954704285,
#   'neg_sentiment': 0.0},
#  '2019-12-08': {'edit_count': 1,
#   'sentiment': -0.9756006002426147,
#   'neg_sentiment': 1.0},
#  '2019-12-10': {'edit_count': 1,
#   'sentiment': -0.9983602166175842,
#   'neg_sentiment': 1.0},
#  '2019-12-14': {'edit_count': 2,
#   'sentiment': 0.00042051076889038086,
#   'neg_sentiment': 0.5},
#  '2019-12-15': {'edit_count': 1,
#   'sentiment': 0.9541179537773132,
#   'neg_sentiment': 0.0},
#  '2020-01-10': {'edit_count': 1,
#   'sentiment': -0.9964649677276611,
#   'neg_sentiment': 1.0},
#  '2020-02-06': {'edit_count': 1,
#   'sentiment': -0.9986720085144043,
#   'neg_sentiment': 1.0},
#  '2020-02-15': {'edit_count': 1,
#   'sentiment': 0.9934669137001038,
#   'neg_sentiment': 0.0},
#  '2020-02-22': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2020-02-26': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2020-03-05': {'edit_count': 1,
#   'sentiment': -0.7419729232788086,
#   'neg_sentiment': 1.0},
#  '2020-03-06': {'edit_count': 2,
#   'sentiment': -0.9986594915390015,
#   'neg_sentiment': 1.0},
#  '2020-04-14': {'edit_count': 1,
#   'sentiment': 0.9034832715988159,
#   'neg_sentiment': 0.0},
#  '2020-05-07': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2020-06-16': {'edit_count': 2,
#   'sentiment': 0.9910717606544495,
#   'neg_sentiment': 0.0},
#  '2020-07-03': {'edit_count': 1,
#   'sentiment': -0.9992515444755554,
#   'neg_sentiment': 1.0},
#  '2020-07-08': {'edit_count': 1,
#   'sentiment': -0.9980660080909729,
#   'neg_sentiment': 1.0},
#  '2020-07-30': {'edit_count': 1,
#   'sentiment': 0.9034832715988159,
#   'neg_sentiment': 0.0},
#  '2020-08-30': {'edit_count': 1,
#   'sentiment': -0.7385990619659424,
#   'neg_sentiment': 1.0},
#  '2020-09-06': {'edit_count': 1,
#   'sentiment': -0.9775174260139465,
#   'neg_sentiment': 1.0},
#  '2020-09-09': {'edit_count': 1,
#   'sentiment': -0.8130719661712646,
#   'neg_sentiment': 1.0},
#  '2020-09-24': {'edit_count': 3,
#   'sentiment': 0.32226012150446576,
#   'neg_sentiment': 0.3333333333333333},
#  '2020-10-06': {'edit_count': 1,
#   'sentiment': 0.9624136090278625,
#   'neg_sentiment': 0.0},
#  '2020-10-27': {'edit_count': 1,
#   'sentiment': -0.9954850673675537,
#   'neg_sentiment': 1.0},
#  '2020-11-06': {'edit_count': 1,
#   'sentiment': -0.9389488101005554,
#   'neg_sentiment': 1.0},
#  '2020-12-20': {'edit_count': 2,
#   'sentiment': -0.9980591833591461,
#   'neg_sentiment': 1.0},
#  '2020-12-26': {'edit_count': 2,
#   'sentiment': -0.9993129372596741,
#   'neg_sentiment': 1.0},
#  '2020-12-28': {'edit_count': 1,
#   'sentiment': 0.9969047904014587,
#   'neg_sentiment': 0.0},
#  '2020-12-29': {'edit_count': 1,
#   'sentiment': -0.9875819683074951,
#   'neg_sentiment': 1.0},
#  '2021-01-23': {'edit_count': 1,
#   'sentiment': 0.9300209879875183,
#   'neg_sentiment': 0.0},
#  '2021-02-09': {'edit_count': 1,
#   'sentiment': -0.9995482563972473,
#   'neg_sentiment': 1.0},
#  '2021-03-09': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-03-11': {'edit_count': 3,
#   'sentiment': -0.9937336047490438,
#   'neg_sentiment': 1.0},
#  '2021-03-15': {'edit_count': 1,
#   'sentiment': 0.9691764712333679,
#   'neg_sentiment': 0.0},
#  '2021-03-29': {'edit_count': 1,
#   'sentiment': 0.9624136090278625,
#   'neg_sentiment': 0.0},
#  '2021-04-04': {'edit_count': 1,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2021-04-14': {'edit_count': 1,
#   'sentiment': 0.9624136090278625,
#   'neg_sentiment': 0.0},
#  '2021-04-20': {'edit_count': 3,
#   'sentiment': 0.30912405252456665,
#   'neg_sentiment': 0.3333333333333333},
#  '2021-04-21': {'edit_count': 1,
#   'sentiment': -0.9902324676513672,
#   'neg_sentiment': 1.0},
#  '2021-04-22': {'edit_count': 1,
#   'sentiment': -0.9824746251106262,
#   'neg_sentiment': 1.0},
#  '2021-05-14': {'edit_count': 1,
#   'sentiment': -0.9978370070457458,
#   'neg_sentiment': 1.0},
#  '2021-05-30': {'edit_count': 1,
#   'sentiment': -0.999659538269043,
#   'neg_sentiment': 1.0},
#  '2021-06-11': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-06-21': {'edit_count': 1,
#   'sentiment': -0.8444913029670715,
#   'neg_sentiment': 1.0},
#  '2021-07-05': {'edit_count': 1,
#   'sentiment': -0.9970635771751404,
#   'neg_sentiment': 1.0},
#  '2021-08-02': {'edit_count': 1,
#   'sentiment': -0.8014745712280273,
#   'neg_sentiment': 1.0},
#  '2021-08-06': {'edit_count': 1,
#   'sentiment': 0.7945832014083862,
#   'neg_sentiment': 0.0},
#  '2021-08-12': {'edit_count': 1,
#   'sentiment': -0.9837926626205444,
#   'neg_sentiment': 1.0},
#  '2021-09-01': {'edit_count': 1,
#   'sentiment': -0.9970632195472717,
#   'neg_sentiment': 1.0},
#  '2021-09-06': {'edit_count': 1,
#   'sentiment': -0.977997362613678,
#   'neg_sentiment': 1.0},
#  '2021-09-07': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-09-16': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-09-25': {'edit_count': 1,
#   'sentiment': 0.9227570295333862,
#   'neg_sentiment': 0.0},
#  '2021-09-29': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-10-03': {'edit_count': 1,
#   'sentiment': 0.9973639845848083,
#   'neg_sentiment': 0.0},
#  '2021-10-04': {'edit_count': 2,
#   'sentiment': 0.06487059593200684,
#   'neg_sentiment': 0.5},
#  '2021-10-06': {'edit_count': 2,
#   'sentiment': -0.02227923274040222,
#   'neg_sentiment': 0.5},
#  '2021-11-12': {'edit_count': 2,
#   'sentiment': -0.0010111629962921143,
#   'neg_sentiment': 0.5},
#  '2021-11-13': {'edit_count': 2,
#   'sentiment': -0.9884146153926849,
#   'neg_sentiment': 1.0},
#  '2021-11-19': {'edit_count': 2,
#   'sentiment': -0.1254654824733734,
#   'neg_sentiment': 0.5},
#  '2021-11-26': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-11-30': {'edit_count': 2,
#   'sentiment': -0.002609163522720337,
#   'neg_sentiment': 0.5},
#  '2021-12-08': {'edit_count': 2,
#   'sentiment': -0.12435126304626465,
#   'neg_sentiment': 0.5},
#  '2021-12-12': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2021-12-24': {'edit_count': 2,
#   'sentiment': -0.12232115864753723,
#   'neg_sentiment': 0.5},
#  '2021-12-30': {'edit_count': 2,
#   'sentiment': -7.486343383789062e-05,
#   'neg_sentiment': 0.5},
#  '2022-01-01': {'edit_count': 1,
#   'sentiment': -0.9988805651664734,
#   'neg_sentiment': 1.0},
#  '2022-01-03': {'edit_count': 1,
#   'sentiment': 0.8476234674453735,
#   'neg_sentiment': 0.0},
#  '2022-01-07': {'edit_count': 2,
#   'sentiment': -0.0006898045539855957,
#   'neg_sentiment': 0.5},
#  '2022-01-12': {'edit_count': 1,
#   'sentiment': -0.9563184976577759,
#   'neg_sentiment': 1.0},
#  '2022-01-15': {'edit_count': 2,
#   'sentiment': -0.0007365942001342773,
#   'neg_sentiment': 0.5},
#  '2022-01-21': {'edit_count': 1,
#   'sentiment': -0.9976634979248047,
#   'neg_sentiment': 1.0},
#  '2022-02-19': {'edit_count': 1,
#   'sentiment': -0.9968063831329346,
#   'neg_sentiment': 1.0},
#  '2022-02-21': {'edit_count': 3,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2022-03-05': {'edit_count': 7,
#   'sentiment': 0.42516110624585834,
#   'neg_sentiment': 0.2857142857142857},
#  '2022-03-06': {'edit_count': 1,
#   'sentiment': -0.9995766282081604,
#   'neg_sentiment': 1.0},
#  '2022-03-09': {'edit_count': 1,
#   'sentiment': 0.9300209879875183,
#   'neg_sentiment': 0.0},
#  '2022-05-06': {'edit_count': 2,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2022-06-02': {'edit_count': 1,
#   'sentiment': 0.9995869994163513,
#   'neg_sentiment': 0.0},
#  '2022-06-09': {'edit_count': 1,
#   'sentiment': -0.9976528286933899,
#   'neg_sentiment': 1.0},
#  '2022-06-13': {'edit_count': 1,
#   'sentiment': -0.9976152181625366,
#   'neg_sentiment': 1.0},
#  '2022-06-14': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2022-08-01': {'edit_count': 1,
#   'sentiment': 0.9796878099441528,
#   'neg_sentiment': 0.0},
#  '2022-08-04': {'edit_count': 2,
#   'sentiment': 0.988134890794754,
#   'neg_sentiment': 0.0},
#  '2022-08-10': {'edit_count': 1,
#   'sentiment': 0.9300209879875183,
#   'neg_sentiment': 0.0},
#  '2022-08-11': {'edit_count': 1,
#   'sentiment': 0.9624136090278625,
#   'neg_sentiment': 0.0},
#  '2022-08-15': {'edit_count': 1,
#   'sentiment': -0.9870957136154175,
#   'neg_sentiment': 1.0},
#  '2022-08-26': {'edit_count': 1,
#   'sentiment': -0.9821085929870605,
#   'neg_sentiment': 1.0},
#  '2022-08-28': {'edit_count': 1,
#   'sentiment': -0.9860072135925293,
#   'neg_sentiment': 1.0},
#  '2022-09-01': {'edit_count': 1,
#   'sentiment': -0.9894366264343262,
#   'neg_sentiment': 1.0},
#  '2022-11-14': {'edit_count': 3,
#   'sentiment': -0.4081553816795349,
#   'neg_sentiment': 0.6666666666666666},
#  '2022-11-20': {'edit_count': 1,
#   'sentiment': -0.9933063387870789,
#   'neg_sentiment': 1.0},
#  '2022-12-11': {'edit_count': 1,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2022-12-18': {'edit_count': 2,
#   'sentiment': -0.9993433654308319,
#   'neg_sentiment': 1.0},
#  '2022-12-19': {'edit_count': 1,
#   'sentiment': -0.9995806813240051,
#   'neg_sentiment': 1.0},
#  '2022-12-20': {'edit_count': 4,
#   'sentiment': -0.1675635129213333,
#   'neg_sentiment': 0.5},
#  '2022-12-21': {'edit_count': 1,
#   'sentiment': 0.9624136090278625,
#   'neg_sentiment': 0.0},
#  '2022-12-22': {'edit_count': 1,
#   'sentiment': -0.9987285733222961,
#   'neg_sentiment': 1.0},
#  '2023-02-10': {'edit_count': 5,
#   'sentiment': -0.2249089479446411,
#   'neg_sentiment': 0.6},
#  '2023-02-28': {'edit_count': 2,
#   'sentiment': -0.12545043230056763,
#   'neg_sentiment': 0.5},
#  '2023-03-07': {'edit_count': 2,
#   'sentiment': -0.03247553110122681,
#   'neg_sentiment': 0.5},
#  '2023-03-25': {'edit_count': 1,
#   'sentiment': -0.9996689558029175,
#   'neg_sentiment': 1.0},
#  '2023-04-07': {'edit_count': 2,
#   'sentiment': -0.12324047088623047,
#   'neg_sentiment': 0.5},
#  '2023-04-17': {'edit_count': 2,
#   'sentiment': 0.8852837681770325,
#   'neg_sentiment': 0.0},
#  '2023-05-13': {'edit_count': 1,
#   'sentiment': -0.9991357922554016,
#   'neg_sentiment': 1.0},
#  '2023-05-20': {'edit_count': 1,
#   'sentiment': -0.9625838994979858,
#   'neg_sentiment': 1.0},
#  '2023-05-26': {'edit_count': 3,
#   'sentiment': 0.748120903968811,
#   'neg_sentiment': 0.0},
#  '2023-06-05': {'edit_count': 1,
#   'sentiment': -0.9917929768562317,
#   'neg_sentiment': 1.0},
#  '2023-06-13': {'edit_count': 1,
#   'sentiment': -0.6183797121047974,
#   'neg_sentiment': 1.0}}

# %%
import pandas as pd

edits_df = pd.DataFrame.from_dict(edits, orient="index")

# %%
edits_df
# Out:
#             edit_count  sentiment  neg_sentiment
# 2005-06-08           3   0.171650       0.333333
# 2005-06-19           1   0.748121       0.000000
# 2005-06-24           1   0.748121       0.000000
# 2005-06-25           2   0.872137       0.000000
# 2005-06-28           1  -0.998648       1.000000
# ...                ...        ...            ...
# 2023-05-13           1  -0.999136       1.000000
# 2023-05-20           1  -0.962584       1.000000
# 2023-05-26           3   0.748121       0.000000
# 2023-06-05           1  -0.991793       1.000000
# 2023-06-13           1  -0.618380       1.000000
#
# [857 rows x 3 columns]

# %%
edits_df.index = pd.to_datetime(edits_df.index)

# %%
from datetime import datetime

dates = pd.date_range(start="2005-06-08",end=datetime.today())

# %%
edits_df = edits_df.reindex(dates, fill_value=0)

# %%
edits_df
# Out:
#             edit_count  sentiment  neg_sentiment
# 2005-06-08           0        0.0            0.0
# 2005-06-09           0        0.0            0.0
# 2005-06-10           0        0.0            0.0
# 2005-06-11           0        0.0            0.0
# 2005-06-12           0        0.0            0.0
# ...                ...        ...            ...
# 2023-07-16           0        0.0            0.0
# 2023-07-17           0        0.0            0.0
# 2023-07-18           0        0.0            0.0
# 2023-07-19           0        0.0            0.0
# 2023-07-20           0        0.0            0.0
#
# [6617 rows x 3 columns]

# %%
rolling_edits = edits_df.rolling(30, min_periods=30).mean()

# %%
rolling_edits = rolling_edits.dropna()

# %%
rolling_edits
# Out:
#             edit_count  sentiment  neg_sentiment
# 2005-07-07         0.0        0.0            0.0
# 2005-07-08         0.0        0.0            0.0
# 2005-07-09         0.0        0.0            0.0
# 2005-07-10         0.0        0.0            0.0
# 2005-07-11         0.0        0.0            0.0
# ...                ...        ...            ...
# 2023-07-16         0.0        0.0            0.0
# 2023-07-17         0.0        0.0            0.0
# 2023-07-18         0.0        0.0            0.0
# 2023-07-19         0.0        0.0            0.0
# 2023-07-20         0.0        0.0            0.0
#
# [6588 rows x 3 columns]

# %%
rolling_edits.to_csv("wikipedia_edits.csv")
